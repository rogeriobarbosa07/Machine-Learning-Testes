# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping

# %%
dataset_train = pd.read_csv("Google_Stock_Price_Train.csv")
dataset_train
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
dataset_train.shape
# Out:
# (1258, 6)

# %%
training_set = dataset_train.iloc[:,1:2].values
training_set
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaler = sc.fit_transform(training_set)
training_set_scaler
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
X_train = []
y_train = []
for i in range(60, 1258):
  X_train.append(training_set_scaler[i-60:i,0])
  y_train.append(training_set_scaler[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(X_train)
# Out:
# [[0.08581368 0.09701243 0.09433366 ... 0.07846566 0.08034452 0.08497656]
#  [0.09701243 0.09433366 0.09156187 ... 0.08034452 0.08497656 0.08627874]
#  [0.09433366 0.09156187 0.07984225 ... 0.08497656 0.08627874 0.08471612]
#  ...
#  [0.92106928 0.92438053 0.93048218 ... 0.95475854 0.95204256 0.95163331]
#  [0.92438053 0.93048218 0.9299055  ... 0.95204256 0.95163331 0.95725128]
#  [0.93048218 0.9299055  0.93113327 ... 0.95163331 0.95725128 0.93796041]]

# %%
X_train.shape
# Out:
# (1198, 60)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (1198, 60, 1)

# %%
modelo = Sequential()
modelo.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelo.add(Dropout(0.2))
modelo.add(LSTM(units=50, return_sequences=True))
modelo.add(Dropout(0.2))
modelo.add(LSTM(units=50))
modelo.add(Dropout(0.2))
modelo.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
modelo.compile(optimizer="adam", loss="mean_squared_error")

es = EarlyStopping(monitor="loss", mode="min", verbose=1, patience=30)

modelo.fit(X_train, y_train, epochs=500, batch_size=32, callbacks=[es])
# Out:
# Epoch 1/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0805
# Epoch 2/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0066
# Epoch 3/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048
# Epoch 4/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0057
# Epoch 5/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0050
# Epoch 6/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0046
# Epoch 7/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042
# Epoch 8/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036
# Epoch 9/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0038
# Epoch 10/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032
# Epoch 11/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039
# Epoch 12/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039
# Epoch 13/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039
# Epoch 14/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029
# Epoch 15/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042
# Epoch 16/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0034
# Epoch 17/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033
# Epoch 18/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035
# Epoch 19/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040
# Epoch 20/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0032
# Epoch 21/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033
# Epoch 22/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034
# Epoch 23/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032
# Epoch 24/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0037
# Epoch 25/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0024
# Epoch 26/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0029
# Epoch 27/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0032
# Epoch 28/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0025
# Epoch 29/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025
# Epoch 30/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029
# Epoch 31/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026
# Epoch 32/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025
# Epoch 33/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029
# Epoch 34/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027
# Epoch 35/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027
# Epoch 36/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027
# Epoch 37/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026
# Epoch 38/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022
# Epoch 39/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025
# Epoch 40/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027
# Epoch 41/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024
# Epoch 42/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022
# Epoch 43/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020
# Epoch 44/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0021
# Epoch 45/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025
# Epoch 46/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022
# Epoch 47/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 48/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024
# Epoch 49/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0024
# Epoch 50/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0020
# Epoch 51/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021
# Epoch 52/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023
# Epoch 53/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022
# Epoch 54/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022
# Epoch 55/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018
# Epoch 56/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 57/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016
# Epoch 58/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018
# Epoch 59/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018
# Epoch 60/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021
# Epoch 61/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019
# Epoch 62/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019
# Epoch 63/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 64/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018
# Epoch 65/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017
# Epoch 66/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016
# Epoch 67/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019
# Epoch 68/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017
# Epoch 69/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015
# Epoch 70/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016
# Epoch 71/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017
# Epoch 72/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0016
# Epoch 73/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017
# Epoch 74/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016
# Epoch 75/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016
# Epoch 76/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015
# Epoch 77/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 78/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015
# Epoch 79/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015
# Epoch 80/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 81/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 82/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 83/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017
# Epoch 84/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 85/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016
# Epoch 86/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 87/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 88/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 89/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 90/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 91/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 92/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 93/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013
# Epoch 94/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 95/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 96/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012
# Epoch 97/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012
# Epoch 98/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 99/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013
# Epoch 100/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 101/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011
# Epoch 102/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 103/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 104/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011
# Epoch 105/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 106/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 107/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 108/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 109/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 110/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 111/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013
# Epoch 112/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 113/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 114/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 115/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010
# Epoch 116/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013
# Epoch 117/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 118/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.9851e-04
# Epoch 119/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012
# Epoch 120/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011
# Epoch 121/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.7998e-04
# Epoch 122/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011
# Epoch 123/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 124/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012
# Epoch 125/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010
# Epoch 126/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013
# Epoch 127/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 128/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 129/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 130/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 131/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 132/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 133/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 134/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 135/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 136/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 137/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011
# Epoch 138/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 139/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011
# Epoch 140/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5076e-04
# Epoch 141/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0928e-04
# Epoch 142/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 143/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011
# Epoch 144/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012
# Epoch 145/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8889e-04
# Epoch 146/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010
# Epoch 147/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6075e-04
# Epoch 148/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 149/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2202e-04
# Epoch 150/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7922e-04
# Epoch 151/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012
# Epoch 152/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6800e-04
# Epoch 153/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7164e-04
# Epoch 154/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011
# Epoch 155/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 156/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 157/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010
# Epoch 158/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5529e-04
# Epoch 159/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011
# Epoch 160/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2782e-04
# Epoch 161/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5758e-04
# Epoch 162/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4988e-04
# Epoch 163/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4119e-04
# Epoch 164/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7538e-04
# Epoch 165/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.9392e-04
# Epoch 166/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011
# Epoch 167/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 168/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.2184e-04
# Epoch 169/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010
# Epoch 170/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.7069e-04
# Epoch 171/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012
# Epoch 172/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012
# Epoch 173/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011
# Epoch 174/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.4745e-04
# Epoch 175/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8578e-04
# Epoch 176/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.8871e-04
# Epoch 177/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.5149e-04
# Epoch 178/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.7015e-04
# Epoch 179/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010
# Epoch 180/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.5685e-04
# Epoch 181/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012
# Epoch 182/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.9861e-04
# Epoch 183/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.1525e-04
# Epoch 184/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010
# Epoch 185/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.6110e-04
# Epoch 186/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.6774e-04
# Epoch 187/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0010
# Epoch 188/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.9902e-04
# Epoch 189/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7927e-04
# Epoch 190/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014
# Epoch 191/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011
# Epoch 192/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8451e-04
# Epoch 193/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0011
# Epoch 194/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 9.2184e-04
# Epoch 195/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 8.9730e-04
# Epoch 196/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.1202e-04
# Epoch 197/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.1361e-04
# Epoch 198/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.2743e-04
# Epoch 199/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 9.3729e-04
# Epoch 200/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0013
# Epoch 201/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.5934e-04
# Epoch 202/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0010
# Epoch 203/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3011e-04
# Epoch 204/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.5255e-04
# Epoch 205/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010
# Epoch 206/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0010
# Epoch 207/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010
# Epoch 208/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0310e-04
# Epoch 209/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8571e-04
# Epoch 210/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0010
# Epoch 211/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.8883e-04
# Epoch 212/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 8.4138e-04
# Epoch 213/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.4542e-04
# Epoch 214/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.8733e-04
# Epoch 215/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.0843e-04
# Epoch 216/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011
# Epoch 217/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8447e-04
# Epoch 218/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010
# Epoch 219/500
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010
# Epoch 219: early stopping

# %%
dataset_test = pd.read_csv("Google_Stock_Price_Test.csv")
real_stock_price = dataset_test.iloc[:,1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis=0)

# %%
inputs = dataset_total[len(dataset_total)-len(dataset_test) - 60:].values
inputs
# Out:
# array([779.  , 779.66, 777.71, 786.66, 783.76, 781.22, 781.65, 779.8 ,
#        787.85, 798.24, 803.3 , 795.  , 804.9 , 816.68, 806.34, 801.  ,
#        808.35, 795.47, 782.89, 778.2 , 767.25, 750.66, 774.5 , 783.4 ,
#        779.94, 791.17, 756.54, 755.6 , 746.97, 755.2 , 766.92, 771.37,
#        762.61, 772.63, 767.73, 764.26, 760.  , 771.53, 770.07, 757.44,
#        744.59, 757.71, 764.73, 761.  , 772.48, 780.  , 785.04, 793.9 ,
#        797.4 , 797.34, 800.4 , 790.22, 796.76, 795.84, 792.36, 790.9 ,
#        790.68, 793.7 , 783.33, 782.75, 778.81, 788.36, 786.08, 795.26,
#        806.4 , 807.86, 805.  , 807.14, 807.48, 807.08, 805.81, 805.12,
#        806.91, 807.25, 822.3 , 829.62, 837.81, 834.71, 814.66, 796.86])

# %%
inputs = inputs.reshape(-1,1)
inputs
# Out:
# array([[779.  ],
#        [779.66],
#        [777.71],
#        [786.66],
#        [783.76],
#        [781.22],
#        [781.65],
#        [779.8 ],
#        [787.85],
#        [798.24],
#        [803.3 ],
#        [795.  ],
#        [804.9 ],
#        [816.68],
#        [806.34],
#        [801.  ],
#        [808.35],
#        [795.47],
#        [782.89],
#        [778.2 ],
#        [767.25],
#        [750.66],
#        [774.5 ],
#        [783.4 ],
#        [779.94],
#        [791.17],
#        [756.54],
#        [755.6 ],
#        [746.97],
#        [755.2 ],
#        [766.92],
#        [771.37],
#        [762.61],
#        [772.63],
#        [767.73],
#        [764.26],
#        [760.  ],
#        [771.53],
#        [770.07],
#        [757.44],
#        [744.59],
#        [757.71],
#        [764.73],
#        [761.  ],
#        [772.48],
#        [780.  ],
#        [785.04],
#        [793.9 ],
#        [797.4 ],
#        [797.34],
#        [800.4 ],
#        [790.22],
#        [796.76],
#        [795.84],
#        [792.36],
#        [790.9 ],
#        [790.68],
#        [793.7 ],
#        [783.33],
#        [782.75],
#        [778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
  X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1]))
predicted_stock_price = modelo.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step

# %%
plt.plot(real_stock_price, color='red', label='Dados reais de ações do Google')
plt.plot(predicted_stock_price, color='blue', label="Dados previstos de ações do Google")
plt.title("Previsões de ações do Google")
plt.xlabel("Tempo")
plt.ylabel("Preços de ações do Google")
plt.legend()
plt.show()
